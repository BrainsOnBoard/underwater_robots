# %%
from stitch import *
from matplotlib import pyplot as plt

plt.imshow(stitch_static('images1', from_left=False))
# Out:
# 20 images loaded
# Diffs loaded from images1/diffs.py
# Mean difference: 62.03007518796992

# %%
plt.imshow(stitch_static_mean('empty_bath_60cm', from_left=False, mean_diff=31))
# Out:
# 40 images loaded
# Mean difference: 31
